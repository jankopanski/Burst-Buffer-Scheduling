# %%
from IPython.core.display import display, HTML
from warnings import filterwarnings
display(HTML("<style>.container { width:100% !important; }</style>"))
filterwarnings(action='ignore')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %matplotlib inline
import os
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from evalys import visu
from evalys.jobset import JobSet

# %%
input_location = 'KTH-1000-workloads'
files_prefix = 'workload-1'

# %%
schedule_files = []
jobs_files = []
for file in os.listdir('../output/' + input_location):
    if file.endswith('_schedule.csv'):
        schedule_files.append(file)
    elif file.endswith('_jobs.csv'):
        jobs_files.append(file)

schedule_files = [os.path.join('../output', input_location, str(file)) for file in sorted(schedule_files)]
jobs_files = [os.path.join('../output', input_location, str(file)) for file in sorted(jobs_files)]
print(schedule_files)
print(jobs_files)
# Out:
# ['../output/KTH-1000-workloads/workload-1_backfill-1_schedule.csv', '../output/KTH-1000-workloads/workload-1_backfill-2_schedule.csv', '../output/KTH-1000-workloads/workload-1_backfill-3_schedule.csv', '../output/KTH-1000-workloads/workload-1_backfill-4_schedule.csv', '../output/KTH-1000-workloads/workload-1_backfill-5_schedule.csv', '../output/KTH-1000-workloads/workload-1_backfill-6_schedule.csv', '../output/KTH-1000-workloads/workload-1_backfill-7_schedule.csv', '../output/KTH-1000-workloads/workload-1_backfill-8_schedule.csv', '../output/KTH-1000-workloads/workload-1_fcfs_schedule.csv', '../output/KTH-1000-workloads/workload-1_filler_schedule.csv', '../output/KTH-1000-workloads/workload-2_backfill-1_schedule.csv', '../output/KTH-1000-workloads/workload-2_backfill-2_schedule.csv', '../output/KTH-1000-workloads/workload-2_backfill-3_schedule.csv', '../output/KTH-1000-workloads/workload-2_backfill-4_schedule.csv', '../output/KTH-1000-workloads/workload-2_backfill-5_schedule.csv', '../output/KTH-1000-workloads/workload-2_backfill-6_schedule.csv', '../output/KTH-1000-workloads/workload-2_backfill-7_schedule.csv', '../output/KTH-1000-workloads/workload-2_backfill-8_schedule.csv', '../output/KTH-1000-workloads/workload-2_fcfs_schedule.csv', '../output/KTH-1000-workloads/workload-2_filler_schedule.csv', '../output/KTH-1000-workloads/workload-3_backfill-1_schedule.csv', '../output/KTH-1000-workloads/workload-3_backfill-2_schedule.csv', '../output/KTH-1000-workloads/workload-3_backfill-3_schedule.csv', '../output/KTH-1000-workloads/workload-3_backfill-4_schedule.csv', '../output/KTH-1000-workloads/workload-3_backfill-5_schedule.csv', '../output/KTH-1000-workloads/workload-3_backfill-6_schedule.csv', '../output/KTH-1000-workloads/workload-3_backfill-7_schedule.csv', '../output/KTH-1000-workloads/workload-3_backfill-8_schedule.csv', '../output/KTH-1000-workloads/workload-3_fcfs_schedule.csv', '../output/KTH-1000-workloads/workload-3_filler_schedule.csv', '../output/KTH-1000-workloads/workload-4_backfill-1_schedule.csv', '../output/KTH-1000-workloads/workload-4_backfill-2_schedule.csv', '../output/KTH-1000-workloads/workload-4_backfill-3_schedule.csv', '../output/KTH-1000-workloads/workload-4_backfill-4_schedule.csv', '../output/KTH-1000-workloads/workload-4_backfill-5_schedule.csv', '../output/KTH-1000-workloads/workload-4_backfill-6_schedule.csv', '../output/KTH-1000-workloads/workload-4_backfill-7_schedule.csv', '../output/KTH-1000-workloads/workload-4_backfill-8_schedule.csv', '../output/KTH-1000-workloads/workload-4_fcfs_schedule.csv', '../output/KTH-1000-workloads/workload-4_filler_schedule.csv', '../output/KTH-1000-workloads/workload-5_backfill-1_schedule.csv', '../output/KTH-1000-workloads/workload-5_backfill-2_schedule.csv', '../output/KTH-1000-workloads/workload-5_backfill-3_schedule.csv', '../output/KTH-1000-workloads/workload-5_backfill-4_schedule.csv', '../output/KTH-1000-workloads/workload-5_backfill-5_schedule.csv', '../output/KTH-1000-workloads/workload-5_backfill-6_schedule.csv', '../output/KTH-1000-workloads/workload-5_backfill-7_schedule.csv', '../output/KTH-1000-workloads/workload-5_backfill-8_schedule.csv', '../output/KTH-1000-workloads/workload-5_fcfs_schedule.csv', '../output/KTH-1000-workloads/workload-5_filler_schedule.csv']
# ['../output/KTH-1000-workloads/workload-1_backfill-1_jobs.csv', '../output/KTH-1000-workloads/workload-1_backfill-2_jobs.csv', '../output/KTH-1000-workloads/workload-1_backfill-3_jobs.csv', '../output/KTH-1000-workloads/workload-1_backfill-4_jobs.csv', '../output/KTH-1000-workloads/workload-1_backfill-5_jobs.csv', '../output/KTH-1000-workloads/workload-1_backfill-6_jobs.csv', '../output/KTH-1000-workloads/workload-1_backfill-7_jobs.csv', '../output/KTH-1000-workloads/workload-1_backfill-8_jobs.csv', '../output/KTH-1000-workloads/workload-1_fcfs_jobs.csv', '../output/KTH-1000-workloads/workload-1_filler_jobs.csv', '../output/KTH-1000-workloads/workload-2_backfill-1_jobs.csv', '../output/KTH-1000-workloads/workload-2_backfill-2_jobs.csv', '../output/KTH-1000-workloads/workload-2_backfill-3_jobs.csv', '../output/KTH-1000-workloads/workload-2_backfill-4_jobs.csv', '../output/KTH-1000-workloads/workload-2_backfill-5_jobs.csv', '../output/KTH-1000-workloads/workload-2_backfill-6_jobs.csv', '../output/KTH-1000-workloads/workload-2_backfill-7_jobs.csv', '../output/KTH-1000-workloads/workload-2_backfill-8_jobs.csv', '../output/KTH-1000-workloads/workload-2_fcfs_jobs.csv', '../output/KTH-1000-workloads/workload-2_filler_jobs.csv', '../output/KTH-1000-workloads/workload-3_backfill-1_jobs.csv', '../output/KTH-1000-workloads/workload-3_backfill-2_jobs.csv', '../output/KTH-1000-workloads/workload-3_backfill-3_jobs.csv', '../output/KTH-1000-workloads/workload-3_backfill-4_jobs.csv', '../output/KTH-1000-workloads/workload-3_backfill-5_jobs.csv', '../output/KTH-1000-workloads/workload-3_backfill-6_jobs.csv', '../output/KTH-1000-workloads/workload-3_backfill-7_jobs.csv', '../output/KTH-1000-workloads/workload-3_backfill-8_jobs.csv', '../output/KTH-1000-workloads/workload-3_fcfs_jobs.csv', '../output/KTH-1000-workloads/workload-3_filler_jobs.csv', '../output/KTH-1000-workloads/workload-4_backfill-1_jobs.csv', '../output/KTH-1000-workloads/workload-4_backfill-2_jobs.csv', '../output/KTH-1000-workloads/workload-4_backfill-3_jobs.csv', '../output/KTH-1000-workloads/workload-4_backfill-4_jobs.csv', '../output/KTH-1000-workloads/workload-4_backfill-5_jobs.csv', '../output/KTH-1000-workloads/workload-4_backfill-6_jobs.csv', '../output/KTH-1000-workloads/workload-4_backfill-7_jobs.csv', '../output/KTH-1000-workloads/workload-4_backfill-8_jobs.csv', '../output/KTH-1000-workloads/workload-4_fcfs_jobs.csv', '../output/KTH-1000-workloads/workload-4_filler_jobs.csv', '../output/KTH-1000-workloads/workload-5_backfill-1_jobs.csv', '../output/KTH-1000-workloads/workload-5_backfill-2_jobs.csv', '../output/KTH-1000-workloads/workload-5_backfill-3_jobs.csv', '../output/KTH-1000-workloads/workload-5_backfill-4_jobs.csv', '../output/KTH-1000-workloads/workload-5_backfill-5_jobs.csv', '../output/KTH-1000-workloads/workload-5_backfill-6_jobs.csv', '../output/KTH-1000-workloads/workload-5_backfill-7_jobs.csv', '../output/KTH-1000-workloads/workload-5_backfill-8_jobs.csv', '../output/KTH-1000-workloads/workload-5_fcfs_jobs.csv', '../output/KTH-1000-workloads/workload-5_filler_jobs.csv']

# %%
metrics = pd.DataFrame()
for file in schedule_files:
    if files_prefix:
        workload_name, schedule_name, _ = os.path.basename(file).split('_')
    else:
        workload_name = None
        schedule_name, _ = os.path.basename(file).split('_')
    if workload_name != files_prefix:
        continue
    print(workload_name, schedule_name)
    df = pd.read_csv(file)
    df['schedule'] = schedule_name
    df = df.set_index('schedule')
    metrics = metrics.append(df)
# Out:
# workload-1 backfill-1
# workload-1 backfill-2
# workload-1 backfill-3
# workload-1 backfill-4
# workload-1 backfill-5
# workload-1 backfill-6
# workload-1 backfill-7
# workload-1 backfill-8
# workload-1 fcfs
# workload-1 filler

# %%
metrics.T
# Out:
# schedule                backfill-1   backfill-2   backfill-3   backfill-4  \
# batsim_version               3.1.0        3.1.0        3.1.0        3.1.0
# consumed_joules                  0            0            0            0
# makespan                    903637       922046       957443  1.09851e+06
# max_slowdown                2730.7      2624.04      13757.8        12276
# max_turnaround_time         245520       215337       246008       334528
# max_waiting_time            164989       169402       213505       292617
# mean_slowdown              25.0432      37.6751      332.634      298.498
# mean_turnaround_time        7453.7      8411.66        24159      29765.4
# mean_waiting_time          3128.99      4087.38      19836.9      25442.3
# nb_computing_machines          109          109          109          109
# nb_grouped_switches              0            0            0            0
# nb_jobs                       1000         1000         1000         1000
# nb_jobs_finished               996          996          996          996
# nb_jobs_killed                  34           32           30           31
# nb_jobs_rejected                 4            4            4            4
# nb_jobs_success                962          964          966          965
# nb_machine_switches              0            0            0            0
# scheduling_time            54.2004      53.4529      117.349      114.453
# simulation_time             56.327      55.3855      119.369      116.297
# success_rate                 0.962        0.964        0.966        0.965
# time_computing         5.51852e+07  5.51535e+07  5.50712e+07  5.51297e+07
# time_idle               3.0775e+07   3.0673e+07  3.56043e+07  4.79581e+07
# time_sleeping                    0            0            0            0
# time_switching_off               0            0            0            0
# time_switching_on                0            0            0            0
# time_unavailable                 0            0            0            0
#
# schedule                backfill-5   backfill-6   backfill-7   backfill-8  \
# batsim_version               3.1.0        3.1.0        3.1.0        3.1.0
# consumed_joules                  0            0            0            0
# makespan               1.11376e+06    1.083e+06  1.13184e+06  1.10004e+06
# max_slowdown               28802.9      29687.9        50715      50719.5
# max_turnaround_time         321251       290485       339326       307528
# max_waiting_time            307864       277098       325939       294141
# mean_slowdown              368.776      445.233      450.648      581.462
# mean_turnaround_time       31655.9      32781.4        36528      38989.5
# mean_waiting_time            27333      28458.7      32203.9        34667
# nb_computing_machines          109          109          109          109
# nb_grouped_switches              0            0            0            0
# nb_jobs                       1000         1000         1000         1000
# nb_jobs_finished               996          996          996          996
# nb_jobs_killed                  33           32           33           33
# nb_jobs_rejected                 4            4            4            4
# nb_jobs_success                963          964          963          963
# nb_machine_switches              0            0            0            0
# scheduling_time            132.043      151.018      181.426      180.434
# simulation_time            133.779      152.809      183.191      182.112
# success_rate                 0.963        0.964        0.963        0.963
# time_computing          5.5117e+07  5.51076e+07   5.5149e+07  5.50931e+07
# time_idle              4.95266e+07  4.65825e+07  5.11581e+07  4.81413e+07
# time_sleeping                    0            0            0            0
# time_switching_off               0            0            0            0
# time_switching_on                0            0            0            0
# time_unavailable                 0            0            0            0
#
# schedule                      fcfs       filler
# batsim_version               3.1.0        3.1.0
# consumed_joules                  0            0
# makespan               1.20044e+06       903637
# max_slowdown                117803      1069.03
# max_turnaround_time         405628       417790
# max_waiting_time            389675       417194
# mean_slowdown              4945.29      28.8148
# mean_turnaround_time        148885      8167.39
# mean_waiting_time           144563      3843.15
# nb_computing_machines          109          109
# nb_grouped_switches              0            0
# nb_jobs                       1000         1000
# nb_jobs_finished               996          996
# nb_jobs_killed                  34           33
# nb_jobs_rejected                 4            4
# nb_jobs_success                962          963
# nb_machine_switches              0            0
# scheduling_time             18.946      19.3723
# simulation_time            20.9343      21.2271
# success_rate                 0.962        0.963
# time_computing          5.5087e+07  5.51513e+07
# time_idle              5.92886e+07  3.05654e+07
# time_sleeping                    0            0
# time_switching_off               0            0
# time_switching_on                0            0
# time_unavailable                 0            0

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4), dpi=140)
metrics['makespan'].plot.bar(title='makespan', ax=axes[0])
metrics['mean_waiting_time'].plot.bar(title='mean_waiting_time', ax=axes[1])
metrics['mean_slowdown'].plot.bar(title='mean_slowdown', ax=axes[2])
fig.tight_layout()

# %%
jobsets = {}
for file in jobs_files:
    if files_prefix:
        workload_name, schedule_name, _ = os.path.basename(file).split('_')
    else:
        workload_name = None
        schedule_name, _ = os.path.basename(file).split('_')
    if workload_name != files_prefix:
        continue
    print(workload_name, schedule_name)
    jobsets[schedule_name] = JobSet.from_csv(file)
# Out:
# workload-1 backfill-1
# workload-1 backfill-2
# workload-1 backfill-3
# workload-1 backfill-4
# workload-1 backfill-5
# workload-1 backfill-6
# workload-1 backfill-7
# workload-1 backfill-8
# workload-1 fcfs
# workload-1 filler

# %%
diff_schedules = ['fcfs', 'backfill-1']

# %%
diff_jobsets = {schedule: jobsets[schedule] for schedule in diff_schedules}
matplotlib.rcParams['figure.figsize'] = 12,4
matplotlib.rcParams['figure.dpi']= 170
visu.gantt.plot_diff_gantt(diff_jobsets)

# %%
matplotlib.rcParams['figure.figsize'] = 12, 2
matplotlib.rcParams['figure.dpi']= 170
visu.lifecycle.plot_lifecycle(jobsets[diff_schedules[0]], title=diff_schedules[0])
visu.lifecycle.plot_lifecycle(jobsets[diff_schedules[1]], title=diff_schedules[1])
