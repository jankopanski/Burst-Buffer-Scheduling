# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from evalys.workload import Workload

# %%
input_location = '../../swf/KTH-SP2-1996-2.1-cln.swf'

# %%
workload = Workload.from_csv(input_location)

# %%
workload.df.execution_time.plot(kind='hist', bins=1000, logy=True, figsize=(20, 10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
exec_hours = workload.df.execution_time / 3600

# %%
exec_hours.plot(kind='hist', bins=1000, logy=True, figsize=(20, 10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
exec_hours[exec_hours <= 15].plot(kind='hist', bins=1000, logy=True, figsize=(20, 10))
# Out:
# <AxesSubplot:ylabel='Frequency'>
